# %% [markdown]
# # Graph Fraud Detector
# Load sample data and metrics after running `bash scripts/run_pipeline.sh`.

# %%
from pathlib import Path
import pandas as pd, json
ROOT = Path('..').resolve()
sample = ROOT / 'data' / 'sample'
print(pd.read_csv(sample / 'accounts.csv')['is_fraud'].value_counts())
m = ROOT / 'reports' / 'metrics.json'
if m.exists():
    print(json.loads(m.read_text()))
